# %%
hairstyles = ["bouffant", "pixie", "dreadlocks", "crew", "bowl", "bob", "mohawk", "flattop"]
prices = [30, 25, 40, 20, 20, 35, 50, 35]
last_week = [2, 3, 5, 8, 4, 4, 6, 2]

print(hairstyles)
print(prices)
print(last_week)
# Out:
# ['bouffant', 'pixie', 'dreadlocks', 'crew', 'bowl', 'bob', 'mohawk', 'flattop']
# [30, 25, 40, 20, 20, 35, 50, 35]
# [2, 3, 5, 8, 4, 4, 6, 2]

# %%
prices = [30, 25, 40, 20, 20, 35, 50, 35]
total_price = 0

for price in prices:
    total_price += price

average_price = total_price / len(prices)

print(average_price)
# Out:
# 31.875

# %%
prices = [30, 25, 40, 20, 20, 35, 50, 35]

# Create a list of new prices by subtracting 5 from each price in the prices list
new_prices = [price - 5 for price in prices]

# Print the new prices
print(new_prices)
# Out:
# [25, 20, 35, 15, 15, 30, 45, 30]

# %%
# Create a variable called total_revenue and set it to 0
total_revenue = 0

# Use a for loop to create a variable i that goes from 0 to len(hairstyles)
for i in range(len(hairstyles)):
  # Add the product of prices[i] and last_week[i] to total_revenue
  total_revenue += prices[i] * last_week[i]

# Print the value of total_revenue
print(total_revenue)

# Find the average daily revenue by dividing total_revenue by 7
average_daily_revenue = total_revenue / 7

# Print the average daily revenue
print(average_daily_revenue)
# Out:
# 1085
# 155.0

# %%
cuts_under_30 = [hairstyle for hairstyle, price in zip(hairstyles, new_prices) if price < 30]
print(cuts_under_30)
# Out:
# ['bouffant', 'pixie', 'crew', 'bowl']
